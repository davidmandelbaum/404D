# %%
import pandas as pd
# Out:
# []

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python2.7/site-packages/pandas/__init__.pyc'>

# %%
import matplotlib

# %%
data = pd.read_csv("Angie_out.csv")

# %%
data
# Out:
#       761760   0
# 0     761779   0
# 1     761780   3
# 2     761800  14
# 3     761820  18
# 4     761840  20
# 5     761860  21
# 6     761920  22
# 7     761960  19
# 8     761980  14
# 9     762000  10
# 10    762020   7
# 11    762040   6
# 12    762080   5
# 13    762120   4
# 14    762200   6
# 15    762240   9
# 16    762260  13
# 17    762280  18
# 18    762300  20
# 19    762360  21
# 20    762480  19
# 21    762500  13
# 22    762520   7
# 23    762540   6
# 24    762560   4
# 25    762620   3
# 26    762700   2
# 27    762740   3
# 28    762760   6
# 29    762780   7
# ...      ...  ..
# 2148  882420  12
# 2149  882440   7
# 2150  882460   4
# 2151  882480   2
# 2152  882600   1
# 2153  882640   4
# 2154  882660   7
# 2155  882680  10
# 2156  882700  13
# 2157  882720  15
# 2158  882760  16
# 2159  882880  14
# 2160  882900  11
# 2161  882920   7
# 2162  882940   6
# 2163  882960   4
# 2164  882980   2
# 2165  883120   6
# 2166  883140   8
# 2167  883160  11
# ...

# %%
data.plot()

# %%
data = pd.read_csv("Baxter_out.csv")

# %%
data
# Out:
#          -20   0
# 0         -1   0
# 1          0   3
# 2         20  20
# 3         40  26
# 4         60  33
# 5         80  39
# 6        100  42
# 7        120  43
# 8        160  44
# 9        240  43
# 10       260  40
# 11       280  31
# 12       300  22
# 13       320  15
# 14       340  10
# 15       360   7
# 16       380   6
# 17       400   4
# 18       420   3
# 19       460   4
# 20       480   6
# 21       500   8
# 22       520  12
# 23       540  17
# 24       560  25
# 25       580  35
# 26       600  41
# 27       620  43
# 28       660  44
# 29       760  43
# ...      ...  ..
# 2995  120940   8
# 2996  120960  14
# 2997  120980  21
# 2998  121000  29
# 2999  121020  35
# 3000  121040  40
# 3001  121060  41
# 3002  121100  40
# 3003  121120  38
# 3004  121140  33
# 3005  121160  23
# 3006  121180  13
# 3007  121200   4
# 3008  121220   0
# 3009  121379   0
# 3010  121380   3
# 3011  121400   8
# 3012  121420  14
# 3013  121440  21
# 3014  121460  28
# ...

# %%
data = pd.read_csv('Baxter_out.csv', header=0)

# %%
data
# Out:
#          -20   0
# 0         -1   0
# 1          0   3
# 2         20  20
# 3         40  26
# 4         60  33
# 5         80  39
# 6        100  42
# 7        120  43
# 8        160  44
# 9        240  43
# 10       260  40
# 11       280  31
# 12       300  22
# 13       320  15
# 14       340  10
# 15       360   7
# 16       380   6
# 17       400   4
# 18       420   3
# 19       460   4
# 20       480   6
# 21       500   8
# 22       520  12
# 23       540  17
# 24       560  25
# 25       580  35
# 26       600  41
# 27       620  43
# 28       660  44
# 29       760  43
# ...      ...  ..
# 2995  120940   8
# 2996  120960  14
# 2997  120980  21
# 2998  121000  29
# 2999  121020  35
# 3000  121040  40
# 3001  121060  41
# 3002  121100  40
# 3003  121120  38
# 3004  121140  33
# 3005  121160  23
# 3006  121180  13
# 3007  121200   4
# 3008  121220   0
# 3009  121379   0
# 3010  121380   3
# 3011  121400   8
# 3012  121420  14
# 3013  121440  21
# 3014  121460  28
# ...

# %%
data = pd.read_csv('Baxter_out.csv', header=0, names=('time', 'depth'))

# %%
data
# Out:
#         time  depth
# 0         -1      0
# 1          0      3
# 2         20     20
# 3         40     26
# 4         60     33
# 5         80     39
# 6        100     42
# 7        120     43
# 8        160     44
# 9        240     43
# 10       260     40
# 11       280     31
# 12       300     22
# 13       320     15
# 14       340     10
# 15       360      7
# 16       380      6
# 17       400      4
# 18       420      3
# 19       460      4
# 20       480      6
# 21       500      8
# 22       520     12
# 23       540     17
# 24       560     25
# 25       580     35
# 26       600     41
# 27       620     43
# 28       660     44
# 29       760     43
# ...      ...    ...
# 2995  120940      8
# 2996  120960     14
# 2997  120980     21
# 2998  121000     29
# 2999  121020     35
# 3000  121040     40
# 3001  121060     41
# 3002  121100     40
# 3003  121120     38
# 3004  121140     33
# 3005  121160     23
# 3006  121180     13
# 3007  121200      4
# ...

# %%
data.plot()

# %%
data.plot(x='time', y='depth')

# %%
data[:500].plot(x='time', y='depth')

# %%
data[:100].plot(x='time', y='depth')

# %%
from pylab import *

# %%
from scipy import *

# %%
fitfunc = lambda p, x:
p[0]*cos(2*pi/p[1]*x+p[2]) + p[3]*x
# Out:
#   File "<ipython-input-19-6b531f6d9274>", line 1
#     fitfunc = lambda p, x:
#                           ^
# SyntaxError: invalid syntax
